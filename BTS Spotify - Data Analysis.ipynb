# %% [markdown]
# # Import Library and Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Downloads/bts_song_dataset.csv", index_col=None, header=0)

# %%
df
# Out:
#                    track_id                                name  \
# 0    249gnXrbfmV8NG6jTEMSwD                        Life Goes On
# 1    3QH8rQGNFX8VLbCgZ7uPTS                      Fly To My Room
# 2    0n2moJpAEWHwaPYYjkzMDl                         Blue & Grey
# 3    4GVwjLRT7oSsKby7Vy8EHr                                Skit
# 4    2FVpOsjT1iquZ3SpCjZ9Ne                           Telepathy
# ..                      ...                                 ...
# 173  0zFiJHcn41PbBeU4pYJdNF      Hormone Sensou - Japanese Ver.
# 174  07RpaipQDG3p4kSEZZVzf9         Let Me Know - Japanese Ver.
# 175  1mD6sDkMeumRzpVF73QrlE       No More Dream - Japanese Ver.
# 176  2ysIgQwwy1dciVCG1sBrNy  Shingeki no Boudan - Japanese Ver.
# 177  2iKJS8ni19b9YC2tIdorJ6                               Iine!
#
#                    album_id  track_number  duration_ms  \
# 0    2qehskW9lYGWfYb0xPZkrS             1       207481
# 1    2qehskW9lYGWfYb0xPZkrS             2       222242
# ...

# %% [markdown]
# # Exploratory

# %%
df.describe()
# Out:
#        track_number    duration_ms  danceability      energy         key  \
# count    178.000000     178.000000    178.000000  178.000000  178.000000
# mean       5.511236  220079.696629      0.627017    0.755989    5.219101
# std        4.642275   41353.691637      0.110394    0.143001    3.665733
# min        1.000000   74746.000000      0.252000    0.271000    0.000000
# 25%        2.000000  199124.250000      0.558500    0.685750    1.250000
# 50%        4.000000  226160.000000      0.622500    0.780000    6.000000
# 75%        8.000000  242242.250000      0.710750    0.862000    8.000000
# max       20.000000  323360.000000      0.890000    0.996000   11.000000
#
#          loudness        mode  speechiness  acousticness  instrumentalness  \
# count  178.000000  178.000000   178.000000    178.000000        178.000000
# mean    -5.157326    0.449438     0.126217      0.100278          0.030831
# std      1.918251    0.498840     0.116576      0.154992          0.145218
# ...

# %%
df_value = pd.DataFrame()
df_value = df[['track_id','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
df_value = df_value.set_index('track_id')

# %%
df_value.corr()
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000 -0.064921 -0.057948  0.160294 -0.051743
# energy               -0.064921  1.000000  0.136634  0.667271 -0.146529
# key                  -0.057948  0.136634  1.000000 -0.033594  0.044713
# loudness              0.160294  0.667271 -0.033594  1.000000 -0.143389
# mode                 -0.051743 -0.146529  0.044713 -0.143389  1.000000
# speechiness          -0.147465  0.016257  0.116307 -0.284749  0.104576
# acousticness         -0.078459 -0.467999  0.034902 -0.522009  0.079217
# instrumentalness      0.095797 -0.314509  0.039781 -0.348358  0.102001
# liveness             -0.204215  0.106506 -0.050767 -0.029430 -0.023901
# valence               0.392156  0.361743  0.035464  0.396928 -0.102119
# tempo                -0.054313  0.109998  0.035320  0.079679 -0.051138
#
#                   speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
f, ax = plt.subplots(figsize=(15, 6))

ax = sns.heatmap(df_value.corr(), annot=True, cmap="coolwarm")

# %% [markdown]
# **Positive** correlation
# - Loudness & Energy 0.67
# - Loudness & Valence 0.4
# - Valence & Danceability 0.39
# - Energy & Valence 0.36
#
# **Negative** correlation
# - Loudness & Acousticness -0.52
# - Energy & Acousticness -0.47
# - Loudness & Instrumentalness -0.35
# - Energy & Instrumentalness -0.31

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="loudness", data=df.sort_values(by=['loudness'], ascending = False).head(10),
                color="lightcoral", saturation=.5)

plt.title("Songs with Highest Loudness", fontsize=16)
plt.xlabel("Loudness Score")
plt.ylabel("Song Name")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 34880 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 27735 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28057 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 34880 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="energy", data=df.sort_values(by=['energy'], ascending = False).head(10),
                color="lightcoral", saturation=.5)

plt.title("Songs with Highest Energy", fontsize=16)
plt.xlabel("Energy Score")
plt.ylabel("Song Name")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="valence", data=df.sort_values(by=['valence'], ascending = False).head(10),
                color="lightcoral", saturation=.5)

plt.title("Songs with Highest Valence", fontsize=16)
plt.xlabel("Valence Score")
plt.ylabel("Song Name")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="danceability", data=df.sort_values(by=['danceability'], ascending = False).head(10),
                color="lightcoral", saturation=.5)

plt.title("Songs with Highest Danceability", fontsize=16)
plt.xlabel("Danceability Score")
plt.ylabel("Song Name")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="instrumentalness", data=df.sort_values(by=['instrumentalness'], ascending = False).head(10),
                color="lightskyblue", saturation=.5)

plt.title("Songs with Highest Instrumentalness", fontsize=16)
plt.xlabel("Instrumentalness Score")
plt.ylabel("Song Name")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="acousticness", data=df.sort_values(by=['acousticness'], ascending = False).head(10),
                color="lightskyblue", saturation=.5)

plt.title("Songs with Highest Acousticness", fontsize=16)
plt.xlabel("Acousticness Score")
plt.ylabel("Song Name")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="liveness", data=df.sort_values(by=['liveness'], ascending = False).head(10),
                color="olive", saturation=.5)

plt.title("Songs with Highest Liveness", fontsize=16)
plt.xlabel("Liveness Score")
plt.ylabel("Song Name")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="tempo", data=df.sort_values(by=['tempo'], ascending = False).head(10),
                color="plum", saturation=.5)

plt.title("Songs with Highest Tempo", fontsize=16)
plt.xlabel("Tempo Score")
plt.ylabel("Song Name")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 3))

sns.set_theme(style="whitegrid")

ax = sns.barplot(y="name", x="speechiness", data=df.sort_values(by=['speechiness'], ascending = False).head(10),
                color="grey", saturation=.5)

plt.title("Songs with Highest Speechiness", fontsize=16)
plt.xlabel("Speechiness Score")
plt.ylabel("Song Name")
plt.show()

# %% [markdown]
# # Clustering

# %%
# merge it together

df_cluster = pd.DataFrame()
df_cluster = df[['track_id','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
df_cluster = df_cluster.set_index('track_id')

# %%
from sklearn.cluster import KMeans

# %%
# Calculate sum of squared distances
ssd = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(df_cluster)
    ssd.append(km.inertia_)

# %%
# Plot sum of squared distances / elbow method
plt.figure(figsize=(10,6))
plt.plot(K, ssd, 'bx-')
plt.xlabel('k')
plt.ylabel('ssd')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters=4)
model = kmeans.fit(df_cluster)

# %%
pred = model.labels_
df_cluster['cluster'] = pred
df_cluster
# Out:
#                         danceability  energy  key  loudness  mode  \
# track_id
# 249gnXrbfmV8NG6jTEMSwD         0.566   0.716    1    -5.733     1
# 3QH8rQGNFX8VLbCgZ7uPTS         0.764   0.526   11    -7.355     1
# 0n2moJpAEWHwaPYYjkzMDl         0.547   0.605    8    -6.755     1
# 4GVwjLRT7oSsKby7Vy8EHr         0.703   0.321    4   -13.135     1
# 2FVpOsjT1iquZ3SpCjZ9Ne         0.787   0.669    5    -4.333     0
# ...                              ...     ...  ...       ...   ...
# 0zFiJHcn41PbBeU4pYJdNF         0.634   0.996    9    -1.108     1
# 07RpaipQDG3p4kSEZZVzf9         0.442   0.831   11    -4.320     0
# 1mD6sDkMeumRzpVF73QrlE         0.666   0.863    2    -4.403     1
# 2ysIgQwwy1dciVCG1sBrNy         0.645   0.972   11    -3.029     0
# 2iKJS8ni19b9YC2tIdorJ6         0.710   0.691    3    -5.560     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# track_id
# ...

# %%
df2 = df_cluster.groupby(['cluster'])['danceability'].describe()
df2
# Out:
#          count      mean       std    min      25%    50%      75%    max
# cluster
# 0         65.0  0.679400  0.086336  0.429  0.61800  0.673  0.74600  0.861
# 1         24.0  0.556542  0.077787  0.439  0.50125  0.552  0.58825  0.720
# 2         44.0  0.590341  0.104766  0.252  0.54700  0.583  0.66300  0.813
# 3         45.0  0.624800  0.127199  0.357  0.56600  0.612  0.71900  0.890

# %%
df2 = df_cluster.groupby(['cluster'])['energy'].describe()
df2
# Out:
#          count      mean       std    min      25%     50%      75%    max
# cluster
# 0         65.0  0.760631  0.152234  0.271  0.70300  0.7970  0.85100  0.972
# 1         24.0  0.826500  0.095708  0.548  0.75625  0.8605  0.90325  0.928
# 2         44.0  0.753068  0.139006  0.386  0.67875  0.7620  0.87125  0.996
# 3         45.0  0.714533  0.142726  0.404  0.61700  0.7580  0.83100  0.903

# %%
df2 = df_cluster.groupby(['cluster'])['key'].describe()
df2
# Out:
#          count      mean       std  min   25%  50%  75%   max
# cluster
# 0         65.0  6.046154  3.646191  0.0  3.00  6.0  9.0  11.0
# 1         24.0  5.291667  3.057125  0.0  2.75  5.0  7.0  10.0
# 2         44.0  4.409091  3.506261  0.0  1.00  3.5  8.0  11.0
# 3         45.0  4.777778  3.993682  0.0  1.00  5.0  9.0  11.0

# %%
df2 = df_cluster.groupby(['cluster'])['loudness'].describe()
df2
# Out:
#          count      mean       std     min      25%     50%     75%    max
# cluster
# 0         65.0 -4.991985  1.856604 -13.135 -5.45300 -4.6500 -3.8200 -1.660
# 1         24.0 -4.527167  1.047236  -6.880 -4.90975 -4.3675 -3.9555 -2.769
# 2         44.0 -5.274591  2.083572 -15.389 -5.71125 -5.1020 -4.3860 -1.108
# 3         45.0 -5.617578  2.117857 -14.260 -6.24400 -5.2220 -4.3200 -2.723

# %%
df2 = df_cluster.groupby(['cluster'])['speechiness'].describe()
df2
# Out:
#          count      mean       std     min     25%      50%    75%    max
# cluster
# 0         65.0  0.126188  0.136439  0.0323  0.0517  0.08900  0.126  0.884
# 1         24.0  0.153258  0.085358  0.0390  0.1017  0.14100  0.222  0.408
# 2         44.0  0.134214  0.120994  0.0302  0.0427  0.07605  0.184  0.429
# 3         45.0  0.104020  0.092248  0.0290  0.0517  0.07560  0.120  0.483

# %%
df2 = df_cluster.groupby(['cluster'])['acousticness'].describe()
df2
# Out:
#          count      mean       std       min       25%      50%       75%  \
# cluster
# 0         65.0  0.089003  0.159765  0.000178  0.005330  0.01850  0.104000
# 1         24.0  0.068404  0.109254  0.000226  0.015300  0.02835  0.063025
# 2         44.0  0.117478  0.170040  0.000371  0.004848  0.02780  0.206250
# 3         45.0  0.116745  0.153943  0.000742  0.022000  0.05390  0.148000
#
#            max
# cluster
# 0        0.864
# 1        0.477
# 2        0.864
# 3        0.704

# %%
df2 = df_cluster.groupby(['cluster'])['liveness'].describe()
df2
# Out:
#          count      mean       std     min      25%     50%    75%    max
# cluster
# 0         65.0  0.216466  0.205152  0.0443  0.09930  0.1320  0.234  0.963
# 1         24.0  0.212642  0.140465  0.0425  0.09540  0.1805  0.319  0.477
# 2         44.0  0.205027  0.150201  0.0536  0.09535  0.1710  0.294  0.720
# 3         45.0  0.135802  0.074871  0.0481  0.08080  0.1290  0.144  0.312

# %%
df2 = df_cluster.groupby(['cluster'])['valence'].describe()
df2
# Out:
#          count      mean       std     min      25%     50%    75%    max
# cluster
# 0         65.0  0.542938  0.187206  0.1690  0.40200  0.5700  0.695  0.893
# 1         24.0  0.494833  0.137888  0.1960  0.38350  0.5400  0.599  0.702
# 2         44.0  0.500016  0.183807  0.0567  0.37275  0.4935  0.652  0.873
# 3         45.0  0.494902  0.219856  0.0806  0.31100  0.4900  0.640  0.929

# %%
df2 = df_cluster.groupby(['cluster'])['tempo'].describe()
df2
# Out:
#          count        mean       std      min        25%       50%        75%  \
# cluster
# 0         65.0  113.809862  6.311196  104.001  109.06300  113.9970  119.91700
# 1         24.0  167.501917  9.438966  153.836  158.02225  169.9225  173.94075
# 2         44.0   90.145318  8.498250   69.552   84.76250   92.9590   97.65725
# 3         45.0  138.687422  7.088072  127.990  131.04900  139.4130  144.99200
#
#              max
# cluster
# 0        126.014
# 1        185.810
# 2        101.085
# 3        149.980

# %%
df_temp = pd.DataFrame(df_cluster[['loudness','energy','valence','danceability','tempo','liveness','key','mode','speechiness','acousticness','instrumentalness','cluster']].groupby(['cluster']).quantile(0.5))
df_temp
# Out:
#          loudness  energy  valence  danceability     tempo  liveness  key  \
# cluster
# 0         -4.6500  0.7970   0.5700         0.673  113.9970    0.1320  6.0
# 1         -4.3675  0.8605   0.5400         0.552  169.9225    0.1805  5.0
# 2         -5.1020  0.7620   0.4935         0.583   92.9590    0.1710  3.5
# 3         -5.2220  0.7580   0.4900         0.612  139.4130    0.1290  5.0
#
#          mode  speechiness  acousticness  instrumentalness
# cluster
# 0         0.0      0.08900       0.01850               0.0
# 1         1.0      0.14100       0.02835               0.0
# 2         1.0      0.07605       0.02780               0.0
# 3         0.0      0.07560       0.05390               0.0

# %%
cm = ['Blues', 'Blues', 'Blues', 'Blues', 'Blues', 'Blues', 'Blues','Blues','Blues','Blues','Blues']
f, axs = plt.subplots(1, df_temp.columns.size, gridspec_kw={'wspace': 0}, figsize=(15, 6))

for i, (s, a, c) in enumerate(zip(df_temp.columns, axs, cm)):
    sns.heatmap(np.array([df_temp[s].values]).T, yticklabels=df_temp.index, xticklabels=[s], annot=True, fmt='.2f', ax=a, cmap=c, cbar=False)
    if i>0:
        a.yaxis.set_ticks([])

plt.title('Heatmap of Cluster Attributes', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Heatmap of Cluster Attributes')

# %% [markdown]
# Cluster 0 : Upbeat songs
# - High danceability, valence, quite high loudness
#
# Cluster 1 : Powerful songs
# - High energy, loudness, tempo, liveness
#
# Cluster 2 : Pop time
# - Quite high liveness, acousticness
#
# Cluster 3 : Chill songs
# - High acousticness, danceability, tempo

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
# merge it together

df_pca = pd.DataFrame()
df_pca = df[['track_id','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
df_pca = df_pca.set_index('track_id')

# %%
pca = PCA(n_components=3)
pca_result = pca.fit_transform(df_pca.values)
df_pca['pca-one'] = pca_result[:,0]
df_pca['pca-two'] = pca_result[:,1] 
df_pca['pca-three'] = pca_result[:,2]

# %%
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.97509229 0.01913762 0.00524447]

# %%
df_pca['cluster'] = pred
df_pca
# Out:
#                         danceability  energy  key  loudness  mode  \
# track_id
# 249gnXrbfmV8NG6jTEMSwD         0.566   0.716    1    -5.733     1
# 3QH8rQGNFX8VLbCgZ7uPTS         0.764   0.526   11    -7.355     1
# 0n2moJpAEWHwaPYYjkzMDl         0.547   0.605    8    -6.755     1
# 4GVwjLRT7oSsKby7Vy8EHr         0.703   0.321    4   -13.135     1
# 2FVpOsjT1iquZ3SpCjZ9Ne         0.787   0.669    5    -4.333     0
# ...                              ...     ...  ...       ...   ...
# 0zFiJHcn41PbBeU4pYJdNF         0.634   0.996    9    -1.108     1
# 07RpaipQDG3p4kSEZZVzf9         0.442   0.831   11    -4.320     0
# 1mD6sDkMeumRzpVF73QrlE         0.666   0.863    2    -4.403     1
# 2ysIgQwwy1dciVCG1sBrNy         0.645   0.972   11    -3.029     0
# 2iKJS8ni19b9YC2tIdorJ6         0.710   0.691    3    -5.560     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# track_id
# ...

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="cluster",
    data=df_pca,
    legend="full",
    alpha=0.3
)
plt.title("2D PCA Visualization with 3 Components", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(
    x="pca-one", y="pca-three",
    hue="cluster",
    data=df_pca,
    legend="full",
    alpha=0.3
)
plt.title("2D PCA Visualization with 3 Components", fontsize=16)
plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
sctt = ax.scatter(
    xs = df_pca["pca-one"], 
    ys = df_pca["pca-two"], 
    zs = df_pca["pca-three"], 
    c = df_pca["cluster"]
)

ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')

plt.title("3D PCA Visualization with 3 Components", fontsize=16)

cb = plt.colorbar(sctt, ax=ax, shrink=0.3, aspect=4, pad=0.1)
cb.set_ticks([0,1,2,3])

plt.show()

# %% [markdown]
# # t-SNE

# %%
from sklearn.manifold import TSNE

# %%
# merge it together

df_tsne = pd.DataFrame()
df_tsne = df[['track_id','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
df_tsne = df_tsne.set_index('track_id')

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(df_tsne)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 178 samples in 0.000s...
# [t-SNE] Computed neighbors for 178 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 178 / 178
# [t-SNE] Mean sigma: 8.328402
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 48.863194
# [t-SNE] KL divergence after 300 iterations: 0.125373

# %%
df_tsne['cluster'] = pred
df_tsne
# Out:
#                         danceability  energy  key  loudness  mode  \
# track_id
# 249gnXrbfmV8NG6jTEMSwD         0.566   0.716    1    -5.733     1
# 3QH8rQGNFX8VLbCgZ7uPTS         0.764   0.526   11    -7.355     1
# 0n2moJpAEWHwaPYYjkzMDl         0.547   0.605    8    -6.755     1
# 4GVwjLRT7oSsKby7Vy8EHr         0.703   0.321    4   -13.135     1
# 2FVpOsjT1iquZ3SpCjZ9Ne         0.787   0.669    5    -4.333     0
# ...                              ...     ...  ...       ...   ...
# 0zFiJHcn41PbBeU4pYJdNF         0.634   0.996    9    -1.108     1
# 07RpaipQDG3p4kSEZZVzf9         0.442   0.831   11    -4.320     0
# 1mD6sDkMeumRzpVF73QrlE         0.666   0.863    2    -4.403     1
# 2ysIgQwwy1dciVCG1sBrNy         0.645   0.972   11    -3.029     0
# 2iKJS8ni19b9YC2tIdorJ6         0.710   0.691    3    -5.560     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# track_id
# ...

# %%
df_tsne['tsne-2d-one'] = tsne_results[:,0]
df_tsne['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="cluster",
    palette=sns.color_palette("hls", 4),
    data=df_tsne,
    legend="full",
    alpha=0.3
)

plt.title("t-SNE 2D Visualization", fontsize=16)
# Out:
# Text(0.5, 1.0, 't-SNE 2D Visualization')

# %%
df_ref = pd.DataFrame(df[['track_id','name']])
df_ref = df_ref.set_index('track_id')
df_ref
# Out:
#                                                       name
# track_id
# 249gnXrbfmV8NG6jTEMSwD                        Life Goes On
# 3QH8rQGNFX8VLbCgZ7uPTS                      Fly To My Room
# 0n2moJpAEWHwaPYYjkzMDl                         Blue & Grey
# 4GVwjLRT7oSsKby7Vy8EHr                                Skit
# 2FVpOsjT1iquZ3SpCjZ9Ne                           Telepathy
# ...                                                    ...
# 0zFiJHcn41PbBeU4pYJdNF      Hormone Sensou - Japanese Ver.
# 07RpaipQDG3p4kSEZZVzf9         Let Me Know - Japanese Ver.
# 1mD6sDkMeumRzpVF73QrlE       No More Dream - Japanese Ver.
# 2ysIgQwwy1dciVCG1sBrNy  Shingeki no Boudan - Japanese Ver.
# 2iKJS8ni19b9YC2tIdorJ6                               Iine!
#
# [178 rows x 1 columns]

# %%
df_tsne = df_tsne.join(df_ref)
df_tsne
# Out:
#                         danceability  energy  key  loudness  mode  \
# track_id
# 249gnXrbfmV8NG6jTEMSwD         0.566   0.716    1    -5.733     1
# 3QH8rQGNFX8VLbCgZ7uPTS         0.764   0.526   11    -7.355     1
# 0n2moJpAEWHwaPYYjkzMDl         0.547   0.605    8    -6.755     1
# 4GVwjLRT7oSsKby7Vy8EHr         0.703   0.321    4   -13.135     1
# 2FVpOsjT1iquZ3SpCjZ9Ne         0.787   0.669    5    -4.333     0
# ...                              ...     ...  ...       ...   ...
# 0zFiJHcn41PbBeU4pYJdNF         0.634   0.996    9    -1.108     1
# 07RpaipQDG3p4kSEZZVzf9         0.442   0.831   11    -4.320     0
# 1mD6sDkMeumRzpVF73QrlE         0.666   0.863    2    -4.403     1
# 2ysIgQwwy1dciVCG1sBrNy         0.645   0.972   11    -3.029     0
# 2iKJS8ni19b9YC2tIdorJ6         0.710   0.691    3    -5.560     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# track_id
# ...

# %%
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']), size="small")

# %%
df_tsne2 = pd.DataFrame(df_tsne[df_tsne['cluster']== 2])

plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="cluster",
    palette=dict({2:"cornflowerblue"}),
    data=df_tsne2,
    legend="full",
    alpha=0.3,
)

label_point(df_tsne2['tsne-2d-one'], df_tsne2['tsne-2d-two'], df_tsne2.name, plt.gca())

plt.title("Cluster 2 Components", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Cluster 2 Components')
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 34880 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 27735 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28057 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 34880 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df_tsne0 = pd.DataFrame(df_tsne[df_tsne['cluster']== 0])

plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="cluster",
    palette=dict({0:"salmon"}),
    data=df_tsne0,
    legend="full",
    alpha=0.3,
)

label_point(df_tsne0['tsne-2d-one'], df_tsne0['tsne-2d-two'], df_tsne0.name, plt.gca())

plt.title("Cluster 0 Components", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Cluster 0 Components')

# %%
df_tsne3 = pd.DataFrame(df_tsne[df_tsne['cluster']== 3])

plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="cluster",
    palette=dict({3:"mediumorchid"}),
    data=df_tsne3,
    legend="full",
    alpha=0.3,
)

label_point(df_tsne3['tsne-2d-one'], df_tsne3['tsne-2d-two'], df_tsne3.name, plt.gca())

plt.title("Cluster 3 Components", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Cluster 3 Components')

# %%
df_tsne1 = pd.DataFrame(df_tsne[df_tsne['cluster']== 1])

plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="cluster",
    palette=dict({1:"limegreen"}),
    data=df_tsne1,
    legend="full",
    alpha=0.3,
)

label_point(df_tsne1['tsne-2d-one'], df_tsne1['tsne-2d-two'], df_tsne1.name, plt.gca())

plt.title("Cluster 1 Components", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Cluster 1 Components')

# %%
df_tsne.to_csv("Downloads/bts_song_dataset_results.csv",index=False)
